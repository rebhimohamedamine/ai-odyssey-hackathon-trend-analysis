# %% [markdown]
# # Automate Content Posting at Optimal Engagement Times
# The goal is to let AI schedule and automatically post viral content on TikTok based on trending analysis and best engagement times.
#
# 1. Detect the Best Posting Times
# Already calculated (best_post_time) using trend analysis and Prophet.
#
# 2. Generate Viral Content (Video, Image, Audio, Text)
# Add viral hashtags and trending music.
#
# 3. Automate Posting
# TikTok API (Content Posting API).

# %%
#extract best author from best_author_detection
import pandas as pd
import nbformat
from nbconvert import PythonExporter
best_author_path = '/content/best author detection (1).ipynb'
with open(best_author_path) as f:
  nb = nbformat.read(f, as_version=4)
exporter = PythonExporter()
(body, resources) = exporter.from_notebook_node(nb)
exec(body)
best_author = top_authors['username'].iloc[0]
print(f"The best author is: {best_author}")
# Out:
#                     id  play_count  share_count  comment_count  digg_count  \
# 0  7446111299458698498     4700000        54600           3247      885900
# 1  7446111299458698498     4700000        54600           3247      885900
# 2  7446111299458698498     4700000        54600           3247      885900
# 3  7446111299458698498     4700000        54600           3247      885900
# 4  7446111299458698498     4700000        54600           3247      885900
#
#    collect_count  followers     likes  video_count hashtags  ...  description  \
# 0          88200     709600  30100000          945       []  ...          NaN
# 1          88200     709600  30100000          945       []  ...          NaN
# 2          88200     709600  30100000          945       []  ...          NaN
# 3          88200     709600  30100000          945       []  ...          NaN
# 4          88200     709600  30100000          945       []  ...          NaN
#
# ...

# %%
#extract generated caption from hshtags_NLP
import pandas as pd
import nbformat
from nbconvert import PythonExporter
best_author_path = '/content/hashtags_NLP_(2) (1) (1).ipynb'
with open(best_author_path) as f:
  nb = nbformat.read(f, as_version=4)
exporter = PythonExporter()
(body, resources) = exporter.from_notebook_node(nb)
exec(body)
best_caption = text
print(f"The best caption is: {best_caption}")
# Out:
# 0    ['toji', 'tojifushiguro', 'jjk', 'jujutsukaise...
# 1    ['cat', 'gato', 'batman', 'memestiktok', 'jefe...
# 2             ['spotify', 'fullsong', 'lyrics', 'fyp']
# 3              ['dance', 'tutorial', 'dancechallenge']
# 4    ['kngoc🎀💓', 'xuhuongtiktok', 'sigma', 'fyp', '...
# Name: hashtags, dtype: object
# object
# Top 10 Most Frequent Hashtags:
# [('fyp', 15), ('foryou', 8), ('viral', 5), ('explore', 4), ('foryoupage', 3), ('anime', 3), ('edit', 3), ('animeedit', 2), ('tiktokviral', 2), ('الشعب_الصيني_ماله_حل😂😂', 2)]
# <string>:73: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12471 (\N{KATAKANA LETTER SI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
#extract time to post from engagement_score
import pandas as pd
import nbformat
from nbconvert import PythonExporter
best_time = '/content/engagement_score (6) (1).ipynb'
with open(best_time) as f:
  nb = nbformat.read(f, as_version=4)
exporter = PythonExporter()
(body, resources) = exporter.from_notebook_node(nb)
exec(body)
best_time= l[0]
print(f"The best time to post {best_time}")
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Correlation Matrix:
#                play_count  share_count  comment_count  digg_count
# play_count       1.000000     0.467992       0.358971    0.825355
# share_count      0.467992     1.000000       0.275429    0.691314
# comment_count    0.358971     0.275429       1.000000    0.529634
# digg_count       0.825355     0.691314       0.529634    1.000000
# Top 10 Viral Videos:
#                       id  play_count  share_count  comment_count  digg_count  \
# 236  7438631768900570401   192600000      1000000         121300    19800000
# 229  7438631768900570401   192600000      1000000         121300    19800000
# ...

# %%
import pandas as pd

# Load trending video and music data
videos_df = pd.read_csv("my_dataframe (8).csv")

# Content details
video_path = "/content/outputt_video.mp4"
audio_path = "/content/transcribed_audio_.mp3"
post_time = best_time
author=best_author
caption=best_caption

#print(f"📌 Selected Video: {video_path}")
print(f"🎵 Selected Audio: {audio_path}")
print(f"⏳ Best Posting Time: {post_time}h")
print(f"👤 Best Author: {author}")
print(f"📝 Best Caption: {caption}")
# Out:
# 🎵 Selected Audio: /content/transcribed_audio_.mp3
# ⏳ Best Posting Time: 1h
# 👤 Best Author: bayashi.tiktok
# 📝 Best Caption: From Tunisia to Morocco, cartoon me getting lost in the Maghreb! 🇹🇳🇱🇾🇲🇦  Which country should I explore next?  ⬇️  #fyp #تونس #ليبيا #cartoonme #المغرب
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# !pip install schedule
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ...

# %%
import schedule
import time

def post_content():
    print(f"🚀 Posting viral content at {post_time}h!")
    # Add integration with TikTok/X API here

# Schedule the post at the best time
# Ensure post_time is a string and remove "h"
post_time = str(post_time)  # Convert to string if it's not already
post_time_numeric = post_time.replace("h", "")  # Remove "h" using replace

post_time_formatted = post_time_numeric.zfill(2) # Pad with leading zeros if necessary
post_time = post_time_formatted
schedule.every().day.at(f"{post_time}:00").do(post_content)

# Run
schedule.run_pending()
time.sleep(60)
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import requests

# TikTok API Parameters
ACCESS_TOKEN = "YOUR_ACCESS_TOKEN"
UPLOAD_ENDPOINT = "https://open-api.tiktok.com/post/video/upload/"

# Upload the video to TikTok
def post_on_tiktok(video_path, caption):
    with open(video_path, "rb") as video_file:
        files = {"video": video_file}
        payload = {"access_token": ACCESS_TOKEN, "caption": caption}
        response = requests.post(UPLOAD_ENDPOINT, files=files, data=payload)

    if response.status_code == 200:
        print("Successfully posted on TikTok!")
    else:
        print(f"TikTok Error: {response.text}")

# Example usage
post_on_tiktok(video_path, "New trend with #AI #Viral ")
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# TikTok Error: <html>
# <head><title>404 Not Found</title></head>
# <body bgcolor="white">
# <center><h1>404 Not Found</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
